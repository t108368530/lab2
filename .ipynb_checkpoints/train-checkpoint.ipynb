# %%
# %load_ext lab_black

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import optimizers, utils
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import (
    Activation,
    BatchNormalization,
    Conv2D,
    Conv1D,
    Dense,
    Dropout,
    Flatten,
    MaxPooling2D,
    MaxPooling1D,
    Concatenate,
    GlobalAveragePooling2D,
    Input,
)

print(
    "Version:%s" % tf.__version__,
    "\nCUDA:%s" % tf.test.is_built_with_cuda(),
    "\nGPU:%s" % tf.test.is_built_with_gpu_support(),
)
# Out:
# Version:2.1.0
# CUDA:True
# GPU:True

# %%
trainData = np.load("trainData.npy", allow_pickle=True)
trainLabel = np.load("trainLabel.npy", allow_pickle=True)
validData = np.load("validData.npy", allow_pickle=True)
validLabel = np.load("validLabel.npy", allow_pickle=True)
pitchShiftTestData = np.load("pitchShiftTestData.npy", allow_pickle=True)
pitchShiftTestLabel = np.load("pitchShiftTestLabel.npy", allow_pickle=True)

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
le.fit(trainLabel)
trainLabel = le.transform(trainLabel)
validLabel = le.transform(validLabel)
pitchShiftTestLabel = le.transform(pitchShiftTestLabel)
# le2 = preprocessing.LabelEncoder()
# le2.fit(melTrainLabel)
# melTrainLabel = le2.transform(melTrainLabel)
# melValidLabel = le2.transform(melValidLabel)

# %%
def mlp(shape: int):
    """創建多層感知機
    
    Arguments:
        shape {int} -- [矩陣維度]
    
    Returns:
        Sequential 
    """
    return Sequential(
        [
            Dense(256, input_shape=(shape,), activation="relu"),
            Dropout(0.5),
            Dense(128, activation="relu"),
            Dropout(0.5),
            Dense(128, activation="relu"),
            Dropout(0.5),
            Dense(128, activation="relu"),
            Dense(10, activation="softmax"),
        ]
    )


def cnn(shape: tuple):
    """創建多層二維迴旋積分
    
    Arguments:
        shape {tuple} -- [矩陣維度]
    
    Returns:
        Sequential 
    """
    Concatenate
    shape1, shape2, shape3 = shape
    inputA = Input((shape2, shape3))
    #     inputB = Input((shape2, shape3))
    x_1 = Conv1D(filters=64, kernel_size=32, activation="relu", padding="same",)(inputA)
    #     x_1 = MaxPooling1D(pool_size=8, strides=8)(x_1)
    #     x_1 = Dropout(0.5)(x_1)
    #     x_1 = Conv1D(
    #         filters=32, kernel_size=16, strides=4, activation="relu", padding="same",
    #     )(x_1)
    #     x_1 = MaxPooling1D(pool_size=4, strides=4)(x_1)
    #     x_1 = Dropout(0.5)(x_1)
    x_1 = Flatten()(x_1)
    x_2 = Conv1D(filters=128, kernel_size=32, activation="relu", padding="same",)(
        inputA
    )
    #     x_2 = MaxPooling1D(pool_size=4, strides=4)(x_2)
    #     x_2 = Dropout(0.5)(x_2)
    #     x_2 = Conv1D(
    #         filters=64, kernel_size=16, strides=18, activation="relu", padding="same",
    #     )(x_2)
    #     x_2 = MaxPooling1D(pool_size=2, strides=2)(x_2)
    #     x_2 = Dropout(0.5)(x_2)
    x_2 = Flatten()(x_2)

    combined = Concatenate()([x_1, x_2])
    drop_1 = Dropout(0.7)(combined)
    Den_1 = Dense(256, activation="relu")(drop_1)
    #     Den_1 = Dropout(0.5)(Den_1)
    #     Den_1 = Dense(256, activation="relu")(Den_1)
    #     Den_1 = Dropout(0.5)(Den_1)
    Den_2 = Dense(10, activation="softmax")(Den_1)
    model = Model(inputs=inputA, outputs=Den_2)
    return model

# %%
model = mlp(trainData.shape[1])

# %%
model.compile(
    optimizer=optimizers.SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
trainLabel = utils.to_categorical(trainLabel)
validLabel = utils.to_categorical(validLabel)
pitchShiftTestLabel = utils.to_categorical(pitchShiftTestLabel)

# %%
utils.plot_model(
    model, show_shapes=True,
)

# %%
history = model.fit(
    trainData,
    trainLabel,
    validation_data=(validData, validLabel),
    verbose=0,  # 不顯示過程
    epochs=200,
    batch_size=128,
)
# Out:
# Train on 1000 samples, validate on 100 samples
# Epoch 1/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2055 - accuracy: 0.9400 - val_loss: 0.8802 - val_accuracy: 0.8100
# Epoch 2/100
# 1000/1000 [==============================] - 0s 19us/sample - loss: 0.2245 - accuracy: 0.9320 - val_loss: 0.8612 - val_accuracy: 0.8200
# Epoch 3/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1818 - accuracy: 0.9440 - val_loss: 0.8770 - val_accuracy: 0.8200
# Epoch 4/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.2286 - accuracy: 0.9370 - val_loss: 0.8964 - val_accuracy: 0.8200
# Epoch 5/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1838 - accuracy: 0.9500 - val_loss: 0.8791 - val_accuracy: 0.8300
# Epoch 6/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1534 - accuracy: 0.9480 - val_loss: 0.8728 - val_accuracy: 0.8300
# Epoch 7/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1886 - accuracy: 0.9400 - val_loss: 0.9340 - val_accuracy: 0.8200
# Epoch 8/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1782 - accuracy: 0.9400 - val_loss: 0.9656 - val_accuracy: 0.8000
# Epoch 9/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1654 - accuracy: 0.9460 - val_loss: 0.9854 - val_accuracy: 0.8200
# Epoch 10/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.2076 - accuracy: 0.9370 - val_loss: 1.0009 - val_accuracy: 0.8300
# Epoch 11/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.2055 - accuracy: 0.9320 - val_loss: 0.9934 - val_accuracy: 0.8400
# Epoch 12/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.2146 - accuracy: 0.9340 - val_loss: 0.9532 - val_accuracy: 0.8200
# Epoch 13/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1766 - accuracy: 0.9380 - val_loss: 0.9381 - val_accuracy: 0.8200
# Epoch 14/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1662 - accuracy: 0.9540 - val_loss: 0.9686 - val_accuracy: 0.8100
# Epoch 15/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1649 - accuracy: 0.9430 - val_loss: 0.9640 - val_accuracy: 0.8100
# Epoch 16/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1719 - accuracy: 0.9420 - val_loss: 1.0326 - val_accuracy: 0.8200
# Epoch 17/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1447 - accuracy: 0.9550 - val_loss: 1.0270 - val_accuracy: 0.8300
# Epoch 18/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1283 - accuracy: 0.9600 - val_loss: 0.9903 - val_accuracy: 0.8200
# Epoch 19/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1488 - accuracy: 0.9540 - val_loss: 1.0024 - val_accuracy: 0.8300
# Epoch 20/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1477 - accuracy: 0.9490 - val_loss: 0.9864 - val_accuracy: 0.8300
# Epoch 21/100
# 1000/1000 [==============================] - 0s 19us/sample - loss: 0.1777 - accuracy: 0.9370 - val_loss: 1.0153 - val_accuracy: 0.8200
# Epoch 22/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1484 - accuracy: 0.9550 - val_loss: 1.0493 - val_accuracy: 0.8200
# Epoch 23/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1633 - accuracy: 0.9480 - val_loss: 1.0080 - val_accuracy: 0.8300
# Epoch 24/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1470 - accuracy: 0.9520 - val_loss: 1.0794 - val_accuracy: 0.8200
# Epoch 25/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1707 - accuracy: 0.9500 - val_loss: 1.1100 - val_accuracy: 0.8100
# Epoch 26/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1596 - accuracy: 0.9520 - val_loss: 0.9900 - val_accuracy: 0.8300
# Epoch 27/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1501 - accuracy: 0.9550 - val_loss: 0.9461 - val_accuracy: 0.8500
# Epoch 28/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1239 - accuracy: 0.9650 - val_loss: 0.9307 - val_accuracy: 0.8400
# Epoch 29/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1258 - accuracy: 0.9580 - val_loss: 1.0004 - val_accuracy: 0.8400
# Epoch 30/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1045 - accuracy: 0.9650 - val_loss: 1.0874 - val_accuracy: 0.8200
# Epoch 31/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1648 - accuracy: 0.9510 - val_loss: 1.0409 - val_accuracy: 0.8300
# Epoch 32/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1340 - accuracy: 0.9640 - val_loss: 1.0562 - val_accuracy: 0.8200
# Epoch 33/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1116 - accuracy: 0.9680 - val_loss: 1.0521 - val_accuracy: 0.8500
# Epoch 34/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1359 - accuracy: 0.9610 - val_loss: 1.0102 - val_accuracy: 0.8400
# Epoch 35/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1476 - accuracy: 0.9520 - val_loss: 0.9990 - val_accuracy: 0.8400
# Epoch 36/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1225 - accuracy: 0.9590 - val_loss: 0.9935 - val_accuracy: 0.8300
# Epoch 37/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1155 - accuracy: 0.9620 - val_loss: 1.0079 - val_accuracy: 0.8200
# Epoch 38/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1297 - accuracy: 0.9610 - val_loss: 1.0578 - val_accuracy: 0.8300
# Epoch 39/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1477 - accuracy: 0.9510 - val_loss: 1.1172 - val_accuracy: 0.8200
# Epoch 40/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1095 - accuracy: 0.9660 - val_loss: 1.0674 - val_accuracy: 0.8200
# Epoch 41/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1223 - accuracy: 0.9610 - val_loss: 1.0595 - val_accuracy: 0.8400
# Epoch 42/100
# 1000/1000 [==============================] - 0s 19us/sample - loss: 0.1259 - accuracy: 0.9570 - val_loss: 1.0653 - val_accuracy: 0.8400
# Epoch 43/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1161 - accuracy: 0.9690 - val_loss: 1.0618 - val_accuracy: 0.8400
# Epoch 44/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0884 - accuracy: 0.9660 - val_loss: 1.1208 - val_accuracy: 0.8400
# Epoch 45/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1533 - accuracy: 0.9530 - val_loss: 1.0902 - val_accuracy: 0.8400
# Epoch 46/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1258 - accuracy: 0.9610 - val_loss: 1.0681 - val_accuracy: 0.8400
# Epoch 47/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1098 - accuracy: 0.9620 - val_loss: 1.0383 - val_accuracy: 0.8300
# Epoch 48/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0957 - accuracy: 0.9690 - val_loss: 1.0991 - val_accuracy: 0.8100
# Epoch 49/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1108 - accuracy: 0.9640 - val_loss: 1.1338 - val_accuracy: 0.8200
# Epoch 50/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.0954 - accuracy: 0.9680 - val_loss: 1.1968 - val_accuracy: 0.8200
# Epoch 51/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1142 - accuracy: 0.9670 - val_loss: 1.1588 - val_accuracy: 0.8200
# Epoch 52/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1205 - accuracy: 0.9640 - val_loss: 1.0010 - val_accuracy: 0.8300
# Epoch 53/100
# 1000/1000 [==============================] - 0s 19us/sample - loss: 0.0954 - accuracy: 0.9680 - val_loss: 1.0148 - val_accuracy: 0.8400
# Epoch 54/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.0926 - accuracy: 0.9710 - val_loss: 1.0761 - val_accuracy: 0.8500
# Epoch 55/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1161 - accuracy: 0.9670 - val_loss: 1.1130 - val_accuracy: 0.8300
# Epoch 56/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1035 - accuracy: 0.9680 - val_loss: 1.1734 - val_accuracy: 0.8300
# Epoch 57/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1210 - accuracy: 0.9650 - val_loss: 1.0845 - val_accuracy: 0.8300
# Epoch 58/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0884 - accuracy: 0.9700 - val_loss: 1.0160 - val_accuracy: 0.8400
# Epoch 59/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0666 - accuracy: 0.9790 - val_loss: 1.0227 - val_accuracy: 0.8500
# Epoch 60/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0892 - accuracy: 0.9710 - val_loss: 1.0463 - val_accuracy: 0.8400
# Epoch 61/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1189 - accuracy: 0.9670 - val_loss: 1.0409 - val_accuracy: 0.8600
# Epoch 62/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1061 - accuracy: 0.9700 - val_loss: 0.9908 - val_accuracy: 0.8400
# Epoch 63/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1048 - accuracy: 0.9670 - val_loss: 0.9884 - val_accuracy: 0.8500
# Epoch 64/100
# 1000/1000 [==============================] - 0s 19us/sample - loss: 0.1184 - accuracy: 0.9640 - val_loss: 1.0418 - val_accuracy: 0.8400
# Epoch 65/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0934 - accuracy: 0.9750 - val_loss: 1.0767 - val_accuracy: 0.8100
# Epoch 66/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0836 - accuracy: 0.9800 - val_loss: 1.0710 - val_accuracy: 0.8400
# Epoch 67/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0972 - accuracy: 0.9710 - val_loss: 1.0557 - val_accuracy: 0.8300
# Epoch 68/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0975 - accuracy: 0.9760 - val_loss: 1.1096 - val_accuracy: 0.8400
# Epoch 69/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0938 - accuracy: 0.9770 - val_loss: 1.1160 - val_accuracy: 0.8200
# Epoch 70/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1198 - accuracy: 0.9610 - val_loss: 1.1279 - val_accuracy: 0.8100
# Epoch 71/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1029 - accuracy: 0.9670 - val_loss: 1.1055 - val_accuracy: 0.8200
# Epoch 72/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0895 - accuracy: 0.9760 - val_loss: 1.0844 - val_accuracy: 0.8300
# Epoch 73/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.0933 - accuracy: 0.9690 - val_loss: 1.0125 - val_accuracy: 0.8500
# Epoch 74/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1227 - accuracy: 0.9650 - val_loss: 1.0020 - val_accuracy: 0.8500
# Epoch 75/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1177 - accuracy: 0.9670 - val_loss: 0.9603 - val_accuracy: 0.8700
# Epoch 76/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1120 - accuracy: 0.9680 - val_loss: 0.9934 - val_accuracy: 0.8500
# Epoch 77/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0839 - accuracy: 0.9760 - val_loss: 1.0389 - val_accuracy: 0.8500
# Epoch 78/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1025 - accuracy: 0.9720 - val_loss: 1.0247 - val_accuracy: 0.8600
# Epoch 79/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1156 - accuracy: 0.9640 - val_loss: 0.9882 - val_accuracy: 0.8500
# Epoch 80/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.0797 - accuracy: 0.9800 - val_loss: 1.0139 - val_accuracy: 0.8500
# Epoch 81/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.0711 - accuracy: 0.9800 - val_loss: 1.0242 - val_accuracy: 0.8500
# Epoch 82/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0858 - accuracy: 0.9700 - val_loss: 0.9585 - val_accuracy: 0.8700
# Epoch 83/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1096 - accuracy: 0.9630 - val_loss: 0.9827 - val_accuracy: 0.8700
# Epoch 84/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1076 - accuracy: 0.9660 - val_loss: 1.0715 - val_accuracy: 0.8300
# Epoch 85/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0649 - accuracy: 0.9790 - val_loss: 1.0610 - val_accuracy: 0.8200
# Epoch 86/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0974 - accuracy: 0.9690 - val_loss: 1.0380 - val_accuracy: 0.8600
# Epoch 87/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.1115 - accuracy: 0.9690 - val_loss: 1.0340 - val_accuracy: 0.8500
# Epoch 88/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0831 - accuracy: 0.9720 - val_loss: 1.0610 - val_accuracy: 0.8500
# Epoch 89/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.0980 - accuracy: 0.9660 - val_loss: 1.0809 - val_accuracy: 0.8400
# Epoch 90/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0749 - accuracy: 0.9750 - val_loss: 1.0799 - val_accuracy: 0.8500
# Epoch 91/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0734 - accuracy: 0.9750 - val_loss: 1.0980 - val_accuracy: 0.8500
# Epoch 92/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.0729 - accuracy: 0.9810 - val_loss: 1.0682 - val_accuracy: 0.8500
# Epoch 93/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0728 - accuracy: 0.9720 - val_loss: 1.0799 - val_accuracy: 0.8500
# Epoch 94/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0967 - accuracy: 0.9700 - val_loss: 1.1071 - val_accuracy: 0.8400
# Epoch 95/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.0839 - accuracy: 0.9740 - val_loss: 1.1055 - val_accuracy: 0.8600
# Epoch 96/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0800 - accuracy: 0.9730 - val_loss: 1.0711 - val_accuracy: 0.8400
# Epoch 97/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.0691 - accuracy: 0.9780 - val_loss: 1.0492 - val_accuracy: 0.8400
# Epoch 98/100
# 1000/1000 [==============================] - 0s 18us/sample - loss: 0.1130 - accuracy: 0.9720 - val_loss: 1.0555 - val_accuracy: 0.8300
# Epoch 99/100
# 1000/1000 [==============================] - 0s 17us/sample - loss: 0.0875 - accuracy: 0.9710 - val_loss: 1.0324 - val_accuracy: 0.8600
# Epoch 100/100
# 1000/1000 [==============================] - 0s 19us/sample - loss: 0.0891 - accuracy: 0.9730 - val_loss: 1.0385 - val_accuracy: 0.8500

# %%
model.evaluate(validData, validLabel)
# Out:
# 100/100 [==============================] - 0s 60us/sample - loss: 1.0385 - accuracy: 0.8500
# [1.0385316177085042, 0.85]

# %%
model.evaluate(pitchShiftTestData, pitchShiftTestLabel)
# Out:
# 100/100 [==============================] - 0s 59us/sample - loss: 0.4822 - accuracy: 0.9100
# [0.4822433304786679, 0.91]

# %%
model2 = cnn(trainData.reshape(1000, 277, 1).shape)
# Out:
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.

# %%
model2.compile(
    optimizer=optimizers.SGD(lr=0.01, momentum=0.9, decay=1e-6, nesterov=True),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
utils.plot_model(
    model2, show_shapes=True,
)

# %%
history2 = model2.fit(
    trainData.reshape(1000, 277, 1),
    trainLabel,
    validation_data=(validData.reshape(100, 277, 1), validLabel),
    verbose=0,  # 不顯示過程
    epochs=25,
    batch_size=128,
)
# Out:
# Train on 1000 samples, validate on 100 samples
# Epoch 1/25
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# 1000/1000 [==============================] - 2s 2ms/sample - loss: 2.1994 - accuracy: 0.2180 - val_loss: 1.8366 - val_accuracy: 0.4800
# Epoch 2/25
# 1000/1000 [==============================] - 0s 84us/sample - loss: 1.5397 - accuracy: 0.6210 - val_loss: 1.2210 - val_accuracy: 0.6000
# Epoch 3/25
# 1000/1000 [==============================] - 0s 84us/sample - loss: 0.8773 - accuracy: 0.7610 - val_loss: 1.0078 - val_accuracy: 0.6600
# Epoch 4/25
# 1000/1000 [==============================] - 0s 91us/sample - loss: 0.5329 - accuracy: 0.8550 - val_loss: 0.9201 - val_accuracy: 0.6900
# Epoch 5/25
# 1000/1000 [==============================] - 0s 95us/sample - loss: 0.3357 - accuracy: 0.9090 - val_loss: 0.8907 - val_accuracy: 0.7000
# Epoch 6/25
# 1000/1000 [==============================] - 0s 95us/sample - loss: 0.2321 - accuracy: 0.9420 - val_loss: 0.9073 - val_accuracy: 0.7300
# Epoch 7/25
# 1000/1000 [==============================] - 0s 93us/sample - loss: 0.1557 - accuracy: 0.9670 - val_loss: 0.9330 - val_accuracy: 0.7000
# Epoch 8/25
# 1000/1000 [==============================] - 0s 96us/sample - loss: 0.1262 - accuracy: 0.9710 - val_loss: 0.8919 - val_accuracy: 0.7000
# Epoch 9/25
# 1000/1000 [==============================] - 0s 93us/sample - loss: 0.0994 - accuracy: 0.9800 - val_loss: 0.9031 - val_accuracy: 0.7000
# Epoch 10/25
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0805 - accuracy: 0.9860 - val_loss: 0.8910 - val_accuracy: 0.6900
# Epoch 11/25
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0647 - accuracy: 0.9940 - val_loss: 0.9111 - val_accuracy: 0.7000
# Epoch 12/25
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0654 - accuracy: 0.9920 - val_loss: 0.8970 - val_accuracy: 0.7000
# Epoch 13/25
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0547 - accuracy: 0.9950 - val_loss: 0.9122 - val_accuracy: 0.7100
# Epoch 14/25
# 1000/1000 [==============================] - 0s 98us/sample - loss: 0.0494 - accuracy: 0.9950 - val_loss: 0.9503 - val_accuracy: 0.7000
# Epoch 15/25
# 1000/1000 [==============================] - 0s 96us/sample - loss: 0.0412 - accuracy: 0.9970 - val_loss: 0.9774 - val_accuracy: 0.6900
# Epoch 16/25
# 1000/1000 [==============================] - 0s 90us/sample - loss: 0.0374 - accuracy: 0.9960 - val_loss: 0.9553 - val_accuracy: 0.6800
# Epoch 17/25
# 1000/1000 [==============================] - 0s 90us/sample - loss: 0.0285 - accuracy: 0.9980 - val_loss: 0.9983 - val_accuracy: 0.7000
# Epoch 18/25
# 1000/1000 [==============================] - 0s 90us/sample - loss: 0.0290 - accuracy: 0.9990 - val_loss: 1.0093 - val_accuracy: 0.6700
# Epoch 19/25
# 1000/1000 [==============================] - 0s 90us/sample - loss: 0.0236 - accuracy: 1.0000 - val_loss: 1.0195 - val_accuracy: 0.6700
# Epoch 20/25
# 1000/1000 [==============================] - 0s 95us/sample - loss: 0.0246 - accuracy: 0.9990 - val_loss: 1.0148 - val_accuracy: 0.6700
# Epoch 21/25
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0302 - accuracy: 0.9970 - val_loss: 0.9598 - val_accuracy: 0.6900
# Epoch 22/25
# 1000/1000 [==============================] - 0s 94us/sample - loss: 0.0237 - accuracy: 0.9970 - val_loss: 1.0144 - val_accuracy: 0.7000
# Epoch 23/25
# 1000/1000 [==============================] - 0s 96us/sample - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.9581 - val_accuracy: 0.7200
# Epoch 24/25
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0170 - accuracy: 0.9990 - val_loss: 0.9471 - val_accuracy: 0.7400
# Epoch 25/25
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0136 - accuracy: 0.9990 - val_loss: 0.9668 - val_accuracy: 0.7000

# %%
model2.evaluate(validData.reshape(100, 277, 1), validLabel)
# Out:
# 100/100 [==============================] - 0s 272us/sample - loss: 0.9668 - accuracy: 0.7000
# [0.9668155694007874, 0.7]

# %%
model2.evaluate(pitchShiftTestData.reshape(100, 277, 1), pitchShiftTestLabel)
# Out:
# 100/100 [==============================] - 0s 116us/sample - loss: 0.4603 - accuracy: 0.9100
# [0.46028230369091033, 0.91]
